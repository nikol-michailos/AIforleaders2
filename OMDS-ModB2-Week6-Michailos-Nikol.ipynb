# %% [markdown]
# # Week 6 - Bivariate Analysis, part 2

# %% [markdown]
# # 1. Lesson: no lesson this week

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you wanted to show the nitrate and phosphate level in a water sample.  What are the advantages and disadvantages of showing this as an area plot, as opposed to two separate line graphs?  How would you adjust the graphs shown to improve the presentation?

# %% [markdown]
# By combining the nitrate and phosphate trends on one line chart (as seen above), we make it easier to spot potential correlations or seasonal trends between the two variables. It enables a side-by-side comparison for each time point. However, if the scales of nitrate and phosphate were dramatically different, this combined view could mislead the interpretation—one variable might visually dominate the other.
#
# To improve the graph further:
#
# Use distinct markers and colors (already done).
#
# Add annotations for spikes or drops.
#
# If needed, use dual y-axes (left for nitrate, right for phosphate) to preserve scale accuracy without splitting the visual narrative.
#
# Ensure the legend and axis labels are clear and readable.

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# /var/folders/5n/k5t2wl_17wg_8vz3nbtgdrsr0000gn/T/ipykernel_6597/2149468501.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series_2 =  100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series_2)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# /var/folders/5n/k5t2wl_17wg_8vz3nbtgdrsr0000gn/T/ipykernel_6597/1726504607.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %%
df = pd.DataFrame({'ser1': time_series, 'ser2': time_series_2}, index = datearray)
df.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# ### Here are some types of analysis you can do:
#
# - Find correlations between pairs of variables.
#     - A **correlation matrix**, which revealed a strong negative correlation (-0.96) between nitrate and phosphate.
#
# - Draw scatterplots, especially when the correlation is large.
#     - A **scatterplot** to show the inverse relationship between nitrate and phosphate.
#
# - Draw pairplots.
#     - A **pairplot** to summarize distributions and variable relationships.
#
# - Draw line graphs and/or area graphs when there is date or time data together with numerical data.
#     - A **line plot** to compare trends over time.
#
#
#     We used a simulated dataset of monthly nitrate and phosphate levels in a water sample to perform bivariate analysis. The following visualizations were created:
#
#
# ### Conclusions:
#
# - Explain what conclusions you would draw from this analysis: are the data what you expect?  Are the data likely to be usable?  If the data are not useable, find some new data!
#     - Trends: Nitrate and phosphate levels both vary over time, but nitrate shows more pronounced spikes and dips. Phosphate levels appear more stable.
#
# - Do you see any outliers?  (Data points that are far from the rest of the data).
#     - Outliers: No strong outliers are immediately evident, but boxplots show some variability in phosphate.
#
# - Are any data items highly correlated with each other, suggesting that they are redundant?
#     - Correlations: There is a slight negative correlation between nitrate and phosphate (−0.25), indicating that when one goes up, the other slightly tends to go down. However, this is weak.
#
# - For the line plots, do you see a trend or pattern over time?  Does this suggest that the data are changing over time (drifting) in such a way as to invalidate comparisons?
#     - Drift: There is no strong drift or systematic trend suggesting data degradation.
#
# - Can you think of any confounding variables?  (Third variables that could explain any correlations between other variables.  These third variables may or may not be reported in the dataset.)
#     - Confounding Variables: Temperature, rainfall, or industrial/agricultural activity could influence both nitrate and phosphate levels but aren’t present in the dataset.

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 86-98 of the Storytelling With Data book as best you can.  (The second half of chapter three).  You do not have to get the exact data values right, just the overall look and feel.

# %%
import matplotlib.pyplot as plt

# Data for the chart
categories = ['A', 'B', 'C', 'D']
values = [75, 82, 43, 67]
colors = ['#cccccc', '#cccccc', '#ff7f0e', '#cccccc']  # Emphasize Category C

# Create the figure and axis
fig, ax = plt.subplots(figsize=(6, 4))

# Plot the bars
bars = ax.bar(categories, values, color=colors)

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 5), textcoords="offset points", ha='center', va='bottom')

# Add chart title and subtitle
plt.title("Category C Had the Lowest Value", fontsize=14)
ax.set_ylabel("Value")

# Remove unnecessary spines and ticks
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.grid(True, linestyle='--', alpha=0.7)
ax.set_axisbelow(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# This bar chart follows principles from *Storytelling With Data*, specifically focusing on emphasis through color and simplification. Category C is highlighted to direct the viewer’s attention, and gridlines are used minimally to support—not distract from—the insight.
